# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import DenseNet201
import matplotlib.pyplot as plt
from keras.utils.vis_utils import plot_model
import numpy as np
from sklearn.metrics import confusion_matrix
import sys

# %%
imsize = 224
batch_size = 32


train_datagen = ImageDataGenerator(
        rotation_range=0.0,
        width_shift_range=0.2,
        height_shift_range=0.0,
        rescale=1. / 255,
        shear_range=0.2,
        zoom_range=0.0,
        validation_split=0.5,
        horizontal_flip=True)

train_generator = train_datagen.flow_from_directory('drive/MyDrive/Database/FRONT/Train',  # this is the target directory
        target_size=(imsize, imsize),  # all images will be resized to 150x150
        batch_size=batch_size, shuffle=True,
        class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)

validation_generator = train_datagen.flow_from_directory('drive/MyDrive/Database/FRONT/Train', # same directory as training data
        target_size=(imsize, imsize),
        batch_size=batch_size,
        class_mode='categorical', shuffle=True,
        subset='validation')  # set as validation data

    # this is a similar generator, for validation data
test_generator = test_datagen.flow_from_directory('drive/MyDrive/Database/FRONT/Test',
        target_size=(imsize, imsize), batch_size=batch_size,
        class_mode='categorical', shuffle=False)

test_generator.reset()
input_shape = (imsize, imsize, 3)
# Out:
# Found 560 images belonging to 2 classes.
# Found 280 images belonging to 2 classes.
# Found 240 images belonging to 2 classes.

# %%
x = keras.layers.Input(input_shape)
base_model =DenseNet201(weights="imagenet",  # Load weights pre-trained on ImageNet.
                        input_shape=(224, 224, 3),
                        include_top=False)
base_model.trainable = False
inputs = keras.Input(shape=(224, 224, 3))
    # We make sure that the base_model is running in inference mode here,
    # by passing `training=False`. This is important for fine-tuning, as you will
    # learn in a few paragraphs.
x = base_model(inputs, training=False)
    # Convert features of shape `base_model.output_shape[1:]` to vectors
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(32, activation='relu')(x)
    # A Dense classifier with a single unit (binary classification)
outputs = keras.layers.Dense(2, activation='softmax')(x)
model = keras.Model(inputs, outputs)
_monitor = keras.callbacks.EarlyStopping(patience=60)
model.compile('Adam', loss='categorical_crossentropy', metrics=['acc', 'mean_absolute_percentage_error', 'AUC'])
model.summary()
checkpoint_filepath = 'drive/MyDrive/Modelli/DenseNet201_100epoch_best_model.hdf5'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_acc',
        mode='max',
        save_best_only=True)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# densenet201 (Functional)     (None, 7, 7, 1920)        18321984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                61472
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 18,383,522
# Trainable params: 61,538
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=False,  show_dtype=False, show_layer_names=True)

# %%
hist = model.fit(
        train_generator, validation_data=validation_generator,
        epochs=100, verbose=2, validation_steps=validation_generator.samples // batch_size,
        callbacks=[model_checkpoint_callback, _monitor])
# Out:
# Epoch 1/100
# 18/18 - 65s - loss: 0.6936 - acc: 0.5446 - mean_absolute_percentage_error: 242576816.0000 - auc: 0.5708 - val_loss: 0.6984 - val_acc: 0.5508 - val_mean_absolute_percentage_error: 246350192.0000 - val_auc: 0.5427
# Epoch 2/100
# 18/18 - 10s - loss: 0.6531 - acc: 0.5964 - mean_absolute_percentage_error: 235061744.0000 - auc: 0.6572 - val_loss: 0.6926 - val_acc: 0.5469 - val_mean_absolute_percentage_error: 245107168.0000 - val_auc: 0.5502
# Epoch 3/100
# 18/18 - 10s - loss: 0.6285 - acc: 0.6429 - mean_absolute_percentage_error: 225926688.0000 - auc: 0.6969 - val_loss: 0.6841 - val_acc: 0.5234 - val_mean_absolute_percentage_error: 239202336.0000 - val_auc: 0.5678
# Epoch 4/100
# 18/18 - 10s - loss: 0.6360 - acc: 0.5893 - mean_absolute_percentage_error: 224264224.0000 - auc: 0.6726 - val_loss: 0.6598 - val_acc: 0.5781 - val_mean_absolute_percentage_error: 235140848.0000 - val_auc: 0.6238
# Epoch 5/100
# 18/18 - 10s - loss: 0.6010 - acc: 0.6839 - mean_absolute_percentage_error: 216327984.0000 - auc: 0.7418 - val_loss: 0.6681 - val_acc: 0.5547 - val_mean_absolute_percentage_error: 234054512.0000 - val_auc: 0.6170
# Epoch 6/100
# 18/18 - 10s - loss: 0.5873 - acc: 0.6679 - mean_absolute_percentage_error: 209984368.0000 - auc: 0.7505 - val_loss: 0.6537 - val_acc: 0.5898 - val_mean_absolute_percentage_error: 229091008.0000 - val_auc: 0.6415
# Epoch 7/100
# 18/18 - 10s - loss: 0.6011 - acc: 0.6411 - mean_absolute_percentage_error: 210853248.0000 - auc: 0.7190 - val_loss: 0.6327 - val_acc: 0.6328 - val_mean_absolute_percentage_error: 226324032.0000 - val_auc: 0.6788
# Epoch 8/100
# 18/18 - 10s - loss: 0.5760 - acc: 0.6786 - mean_absolute_percentage_error: 207578240.0000 - auc: 0.7668 - val_loss: 0.6565 - val_acc: 0.5742 - val_mean_absolute_percentage_error: 226461632.0000 - val_auc: 0.6501
# Epoch 9/100
# 18/18 - 10s - loss: 0.5537 - acc: 0.7054 - mean_absolute_percentage_error: 198841808.0000 - auc: 0.7931 - val_loss: 0.6176 - val_acc: 0.6367 - val_mean_absolute_percentage_error: 219706480.0000 - val_auc: 0.7023
# Epoch 10/100
# 18/18 - 10s - loss: 0.5549 - acc: 0.7107 - mean_absolute_percentage_error: 200434832.0000 - auc: 0.7905 - val_loss: 0.6089 - val_acc: 0.6094 - val_mean_absolute_percentage_error: 216553440.0000 - val_auc: 0.7173
# Epoch 11/100
# 18/18 - 10s - loss: 0.5324 - acc: 0.7357 - mean_absolute_percentage_error: 193684704.0000 - auc: 0.8211 - val_loss: 0.6029 - val_acc: 0.6680 - val_mean_absolute_percentage_error: 213432544.0000 - val_auc: 0.7370
# Epoch 12/100
# 18/18 - 10s - loss: 0.5179 - acc: 0.7554 - mean_absolute_percentage_error: 188989232.0000 - auc: 0.8409 - val_loss: 0.5983 - val_acc: 0.6367 - val_mean_absolute_percentage_error: 213851712.0000 - val_auc: 0.7255
# Epoch 13/100
# 18/18 - 10s - loss: 0.5261 - acc: 0.7411 - mean_absolute_percentage_error: 188453536.0000 - auc: 0.8187 - val_loss: 0.6004 - val_acc: 0.6406 - val_mean_absolute_percentage_error: 211626896.0000 - val_auc: 0.7247
# Epoch 14/100
# 18/18 - 10s - loss: 0.5066 - acc: 0.7571 - mean_absolute_percentage_error: 181977232.0000 - auc: 0.8373 - val_loss: 0.5799 - val_acc: 0.6758 - val_mean_absolute_percentage_error: 208252096.0000 - val_auc: 0.7539
# Epoch 15/100
# 18/18 - 10s - loss: 0.4956 - acc: 0.7429 - mean_absolute_percentage_error: 178873904.0000 - auc: 0.8490 - val_loss: 0.5732 - val_acc: 0.6836 - val_mean_absolute_percentage_error: 205841776.0000 - val_auc: 0.7714
# Epoch 16/100
# 18/18 - 10s - loss: 0.5017 - acc: 0.7696 - mean_absolute_percentage_error: 181352288.0000 - auc: 0.8440 - val_loss: 0.5628 - val_acc: 0.7148 - val_mean_absolute_percentage_error: 204253760.0000 - val_auc: 0.7842
# Epoch 17/100
# 18/18 - 10s - loss: 0.4908 - acc: 0.7571 - mean_absolute_percentage_error: 177188096.0000 - auc: 0.8470 - val_loss: 0.5888 - val_acc: 0.6484 - val_mean_absolute_percentage_error: 205489616.0000 - val_auc: 0.7421
# Epoch 18/100
# 18/18 - 10s - loss: 0.4875 - acc: 0.7536 - mean_absolute_percentage_error: 176135744.0000 - auc: 0.8538 - val_loss: 0.5708 - val_acc: 0.6758 - val_mean_absolute_percentage_error: 202278240.0000 - val_auc: 0.7657
# Epoch 19/100
# 18/18 - 10s - loss: 0.4671 - acc: 0.7643 - mean_absolute_percentage_error: 169846288.0000 - auc: 0.8669 - val_loss: 0.5681 - val_acc: 0.7031 - val_mean_absolute_percentage_error: 202572528.0000 - val_auc: 0.7629
# Epoch 20/100
# 18/18 - 10s - loss: 0.4714 - acc: 0.7607 - mean_absolute_percentage_error: 169422960.0000 - auc: 0.8610 - val_loss: 0.5602 - val_acc: 0.7188 - val_mean_absolute_percentage_error: 199223792.0000 - val_auc: 0.7809
# Epoch 21/100
# 18/18 - 10s - loss: 0.4720 - acc: 0.7696 - mean_absolute_percentage_error: 169782928.0000 - auc: 0.8596 - val_loss: 0.5287 - val_acc: 0.7266 - val_mean_absolute_percentage_error: 191450144.0000 - val_auc: 0.8160
# Epoch 22/100
# 18/18 - 10s - loss: 0.4613 - acc: 0.7929 - mean_absolute_percentage_error: 165357552.0000 - auc: 0.8673 - val_loss: 0.5275 - val_acc: 0.7266 - val_mean_absolute_percentage_error: 187840736.0000 - val_auc: 0.8096
# Epoch 23/100
# 18/18 - 10s - loss: 0.4712 - acc: 0.7804 - mean_absolute_percentage_error: 166890560.0000 - auc: 0.8582 - val_loss: 0.5336 - val_acc: 0.7344 - val_mean_absolute_percentage_error: 190097408.0000 - val_auc: 0.8095
# Epoch 24/100
# 18/18 - 10s - loss: 0.4611 - acc: 0.7589 - mean_absolute_percentage_error: 163770224.0000 - auc: 0.8623 - val_loss: 0.5538 - val_acc: 0.7031 - val_mean_absolute_percentage_error: 194969264.0000 - val_auc: 0.7818
# Epoch 25/100
# 18/18 - 10s - loss: 0.4473 - acc: 0.7929 - mean_absolute_percentage_error: 159598544.0000 - auc: 0.8764 - val_loss: 0.5488 - val_acc: 0.7070 - val_mean_absolute_percentage_error: 192647024.0000 - val_auc: 0.7854
# Epoch 26/100
# 18/18 - 10s - loss: 0.4519 - acc: 0.7714 - mean_absolute_percentage_error: 161372928.0000 - auc: 0.8723 - val_loss: 0.5102 - val_acc: 0.7773 - val_mean_absolute_percentage_error: 184038016.0000 - val_auc: 0.8408
# Epoch 27/100
# 18/18 - 10s - loss: 0.4542 - acc: 0.7607 - mean_absolute_percentage_error: 161166528.0000 - auc: 0.8672 - val_loss: 0.5203 - val_acc: 0.7383 - val_mean_absolute_percentage_error: 186629408.0000 - val_auc: 0.8162
# Epoch 28/100
# 18/18 - 10s - loss: 0.4359 - acc: 0.8161 - mean_absolute_percentage_error: 157082400.0000 - auc: 0.8900 - val_loss: 0.5113 - val_acc: 0.7305 - val_mean_absolute_percentage_error: 184037568.0000 - val_auc: 0.8267
# Epoch 29/100
# 18/18 - 10s - loss: 0.4318 - acc: 0.7875 - mean_absolute_percentage_error: 153618352.0000 - auc: 0.8849 - val_loss: 0.5246 - val_acc: 0.7344 - val_mean_absolute_percentage_error: 186072768.0000 - val_auc: 0.8150
# Epoch 30/100
# 18/18 - 10s - loss: 0.4204 - acc: 0.8232 - mean_absolute_percentage_error: 152781744.0000 - auc: 0.8994 - val_loss: 0.5438 - val_acc: 0.6953 - val_mean_absolute_percentage_error: 185858816.0000 - val_auc: 0.7903
# Epoch 31/100
# 18/18 - 10s - loss: 0.4413 - acc: 0.7875 - mean_absolute_percentage_error: 152584288.0000 - auc: 0.8723 - val_loss: 0.5042 - val_acc: 0.7734 - val_mean_absolute_percentage_error: 181011408.0000 - val_auc: 0.8390
# Epoch 32/100
# 18/18 - 10s - loss: 0.4157 - acc: 0.8054 - mean_absolute_percentage_error: 151623280.0000 - auc: 0.9006 - val_loss: 0.4977 - val_acc: 0.7461 - val_mean_absolute_percentage_error: 179259056.0000 - val_auc: 0.8441
# Epoch 33/100
# 18/18 - 10s - loss: 0.4245 - acc: 0.8107 - mean_absolute_percentage_error: 150878032.0000 - auc: 0.8880 - val_loss: 0.5211 - val_acc: 0.7227 - val_mean_absolute_percentage_error: 181602288.0000 - val_auc: 0.8086
# Epoch 34/100
# 18/18 - 10s - loss: 0.4060 - acc: 0.7982 - mean_absolute_percentage_error: 145722832.0000 - auc: 0.9020 - val_loss: 0.5074 - val_acc: 0.7266 - val_mean_absolute_percentage_error: 179655888.0000 - val_auc: 0.8279
# Epoch 35/100
# 18/18 - 10s - loss: 0.4444 - acc: 0.7714 - mean_absolute_percentage_error: 153096208.0000 - auc: 0.8699 - val_loss: 0.4811 - val_acc: 0.7812 - val_mean_absolute_percentage_error: 173718256.0000 - val_auc: 0.8593
# Epoch 36/100
# 18/18 - 10s - loss: 0.4055 - acc: 0.8196 - mean_absolute_percentage_error: 143930000.0000 - auc: 0.9022 - val_loss: 0.4900 - val_acc: 0.7617 - val_mean_absolute_percentage_error: 174026320.0000 - val_auc: 0.8426
# Epoch 37/100
# 18/18 - 10s - loss: 0.4157 - acc: 0.8125 - mean_absolute_percentage_error: 147130640.0000 - auc: 0.8943 - val_loss: 0.4683 - val_acc: 0.7891 - val_mean_absolute_percentage_error: 167458864.0000 - val_auc: 0.8711
# Epoch 38/100
# 18/18 - 10s - loss: 0.4025 - acc: 0.8054 - mean_absolute_percentage_error: 144078288.0000 - auc: 0.9026 - val_loss: 0.5120 - val_acc: 0.7148 - val_mean_absolute_percentage_error: 176874752.0000 - val_auc: 0.8184
# Epoch 39/100
# 18/18 - 10s - loss: 0.4101 - acc: 0.8196 - mean_absolute_percentage_error: 145314480.0000 - auc: 0.8983 - val_loss: 0.4752 - val_acc: 0.7852 - val_mean_absolute_percentage_error: 169561600.0000 - val_auc: 0.8583
# Epoch 40/100
# 18/18 - 10s - loss: 0.3838 - acc: 0.8429 - mean_absolute_percentage_error: 137461984.0000 - auc: 0.9191 - val_loss: 0.4405 - val_acc: 0.8359 - val_mean_absolute_percentage_error: 162363536.0000 - val_auc: 0.9001
# Epoch 41/100
# 18/18 - 10s - loss: 0.3920 - acc: 0.8321 - mean_absolute_percentage_error: 141693936.0000 - auc: 0.9118 - val_loss: 0.4444 - val_acc: 0.8047 - val_mean_absolute_percentage_error: 159306832.0000 - val_auc: 0.8820
# Epoch 42/100
# 18/18 - 10s - loss: 0.3725 - acc: 0.8357 - mean_absolute_percentage_error: 133741776.0000 - auc: 0.9199 - val_loss: 0.4903 - val_acc: 0.7695 - val_mean_absolute_percentage_error: 172185200.0000 - val_auc: 0.8438
# Epoch 43/100
# 18/18 - 10s - loss: 0.3997 - acc: 0.7946 - mean_absolute_percentage_error: 137538896.0000 - auc: 0.8974 - val_loss: 0.4885 - val_acc: 0.7539 - val_mean_absolute_percentage_error: 167320896.0000 - val_auc: 0.8427
# Epoch 44/100
# 18/18 - 10s - loss: 0.3891 - acc: 0.8071 - mean_absolute_percentage_error: 135510272.0000 - auc: 0.9049 - val_loss: 0.4601 - val_acc: 0.7891 - val_mean_absolute_percentage_error: 162872512.0000 - val_auc: 0.8704
# Epoch 45/100
# 18/18 - 10s - loss: 0.4171 - acc: 0.7982 - mean_absolute_percentage_error: 144138768.0000 - auc: 0.8906 - val_loss: 0.4609 - val_acc: 0.7773 - val_mean_absolute_percentage_error: 165897216.0000 - val_auc: 0.8716
# Epoch 46/100
# 18/18 - 10s - loss: 0.3838 - acc: 0.8161 - mean_absolute_percentage_error: 137336400.0000 - auc: 0.9118 - val_loss: 0.4962 - val_acc: 0.7578 - val_mean_absolute_percentage_error: 171120080.0000 - val_auc: 0.8345
# Epoch 47/100
# 18/18 - 10s - loss: 0.4021 - acc: 0.8250 - mean_absolute_percentage_error: 137726896.0000 - auc: 0.8995 - val_loss: 0.4557 - val_acc: 0.7422 - val_mean_absolute_percentage_error: 159827456.0000 - val_auc: 0.8640
# Epoch 48/100
# 18/18 - 10s - loss: 0.3764 - acc: 0.8196 - mean_absolute_percentage_error: 132528256.0000 - auc: 0.9159 - val_loss: 0.5164 - val_acc: 0.7578 - val_mean_absolute_percentage_error: 172001360.0000 - val_auc: 0.8220
# Epoch 49/100
# 18/18 - 10s - loss: 0.3783 - acc: 0.8286 - mean_absolute_percentage_error: 134664128.0000 - auc: 0.9130 - val_loss: 0.4461 - val_acc: 0.8242 - val_mean_absolute_percentage_error: 160235744.0000 - val_auc: 0.8873
# Epoch 50/100
# 18/18 - 10s - loss: 0.3738 - acc: 0.8250 - mean_absolute_percentage_error: 132535952.0000 - auc: 0.9160 - val_loss: 0.4375 - val_acc: 0.8125 - val_mean_absolute_percentage_error: 154493568.0000 - val_auc: 0.8837
# Epoch 51/100
# 18/18 - 10s - loss: 0.3813 - acc: 0.8214 - mean_absolute_percentage_error: 133976824.0000 - auc: 0.9125 - val_loss: 0.4386 - val_acc: 0.8125 - val_mean_absolute_percentage_error: 159305744.0000 - val_auc: 0.8908
# Epoch 52/100
# 18/18 - 10s - loss: 0.3713 - acc: 0.8339 - mean_absolute_percentage_error: 129096192.0000 - auc: 0.9181 - val_loss: 0.4643 - val_acc: 0.8008 - val_mean_absolute_percentage_error: 162543744.0000 - val_auc: 0.8670
# Epoch 53/100
# 18/18 - 10s - loss: 0.3707 - acc: 0.8482 - mean_absolute_percentage_error: 127821032.0000 - auc: 0.9174 - val_loss: 0.4179 - val_acc: 0.8438 - val_mean_absolute_percentage_error: 151715984.0000 - val_auc: 0.9043
# Epoch 54/100
# 18/18 - 10s - loss: 0.3512 - acc: 0.8357 - mean_absolute_percentage_error: 125265368.0000 - auc: 0.9296 - val_loss: 0.4186 - val_acc: 0.8047 - val_mean_absolute_percentage_error: 150268608.0000 - val_auc: 0.8933
# Epoch 55/100
# 18/18 - 10s - loss: 0.3535 - acc: 0.8464 - mean_absolute_percentage_error: 124920024.0000 - auc: 0.9259 - val_loss: 0.4277 - val_acc: 0.7969 - val_mean_absolute_percentage_error: 153866144.0000 - val_auc: 0.8885
# Epoch 56/100
# 18/18 - 10s - loss: 0.3539 - acc: 0.8429 - mean_absolute_percentage_error: 125989760.0000 - auc: 0.9278 - val_loss: 0.4329 - val_acc: 0.8008 - val_mean_absolute_percentage_error: 156382720.0000 - val_auc: 0.8930
# Epoch 57/100
# 18/18 - 10s - loss: 0.3632 - acc: 0.8286 - mean_absolute_percentage_error: 126742280.0000 - auc: 0.9204 - val_loss: 0.4515 - val_acc: 0.7656 - val_mean_absolute_percentage_error: 155570096.0000 - val_auc: 0.8647
# Epoch 58/100
# 18/18 - 10s - loss: 0.3534 - acc: 0.8339 - mean_absolute_percentage_error: 124784256.0000 - auc: 0.9243 - val_loss: 0.3929 - val_acc: 0.8242 - val_mean_absolute_percentage_error: 145281024.0000 - val_auc: 0.9189
# Epoch 59/100
# 18/18 - 10s - loss: 0.3419 - acc: 0.8429 - mean_absolute_percentage_error: 123179184.0000 - auc: 0.9333 - val_loss: 0.4371 - val_acc: 0.8125 - val_mean_absolute_percentage_error: 152551520.0000 - val_auc: 0.8819
# Epoch 60/100
# 18/18 - 10s - loss: 0.3528 - acc: 0.8321 - mean_absolute_percentage_error: 122360672.0000 - auc: 0.9220 - val_loss: 0.4990 - val_acc: 0.7344 - val_mean_absolute_percentage_error: 157842176.0000 - val_auc: 0.8320
# Epoch 61/100
# 18/18 - 10s - loss: 0.3534 - acc: 0.8321 - mean_absolute_percentage_error: 121437016.0000 - auc: 0.9223 - val_loss: 0.4039 - val_acc: 0.8047 - val_mean_absolute_percentage_error: 144067328.0000 - val_auc: 0.9041
# Epoch 62/100
# 18/18 - 10s - loss: 0.3579 - acc: 0.8250 - mean_absolute_percentage_error: 125466928.0000 - auc: 0.9194 - val_loss: 0.4697 - val_acc: 0.7812 - val_mean_absolute_percentage_error: 152150448.0000 - val_auc: 0.8554
# Epoch 63/100
# 18/18 - 10s - loss: 0.4132 - acc: 0.7911 - mean_absolute_percentage_error: 131997464.0000 - auc: 0.8884 - val_loss: 0.4099 - val_acc: 0.8086 - val_mean_absolute_percentage_error: 145198752.0000 - val_auc: 0.9005
# Epoch 64/100
# 18/18 - 10s - loss: 0.3666 - acc: 0.8250 - mean_absolute_percentage_error: 126473584.0000 - auc: 0.9165 - val_loss: 0.4023 - val_acc: 0.8047 - val_mean_absolute_percentage_error: 143667328.0000 - val_auc: 0.9038
# Epoch 65/100
# 18/18 - 10s - loss: 0.3448 - acc: 0.8411 - mean_absolute_percentage_error: 120900904.0000 - auc: 0.9290 - val_loss: 0.4207 - val_acc: 0.8164 - val_mean_absolute_percentage_error: 146153264.0000 - val_auc: 0.8906
# Epoch 66/100
# 18/18 - 10s - loss: 0.3604 - acc: 0.8304 - mean_absolute_percentage_error: 123239904.0000 - auc: 0.9179 - val_loss: 0.4412 - val_acc: 0.8125 - val_mean_absolute_percentage_error: 153354032.0000 - val_auc: 0.8798
# Epoch 67/100
# 18/18 - 10s - loss: 0.3388 - acc: 0.8304 - mean_absolute_percentage_error: 119285768.0000 - auc: 0.9307 - val_loss: 0.4083 - val_acc: 0.8047 - val_mean_absolute_percentage_error: 146554096.0000 - val_auc: 0.9018
# Epoch 68/100
# 18/18 - 10s - loss: 0.3530 - acc: 0.8071 - mean_absolute_percentage_error: 122095624.0000 - auc: 0.9194 - val_loss: 0.3869 - val_acc: 0.8203 - val_mean_absolute_percentage_error: 141074608.0000 - val_auc: 0.9180
# Epoch 69/100
# 18/18 - 10s - loss: 0.3516 - acc: 0.8411 - mean_absolute_percentage_error: 120878440.0000 - auc: 0.9244 - val_loss: 0.4112 - val_acc: 0.8164 - val_mean_absolute_percentage_error: 145533216.0000 - val_auc: 0.8990
# Epoch 70/100
# 18/18 - 10s - loss: 0.3594 - acc: 0.8393 - mean_absolute_percentage_error: 120860592.0000 - auc: 0.9199 - val_loss: 0.4891 - val_acc: 0.7422 - val_mean_absolute_percentage_error: 153491440.0000 - val_auc: 0.8396
# Epoch 71/100
# 18/18 - 10s - loss: 0.3629 - acc: 0.8339 - mean_absolute_percentage_error: 125718792.0000 - auc: 0.9196 - val_loss: 0.3634 - val_acc: 0.8633 - val_mean_absolute_percentage_error: 134741344.0000 - val_auc: 0.9354
# Epoch 72/100
# 18/18 - 10s - loss: 0.3574 - acc: 0.8446 - mean_absolute_percentage_error: 123283560.0000 - auc: 0.9218 - val_loss: 0.3748 - val_acc: 0.8359 - val_mean_absolute_percentage_error: 135287584.0000 - val_auc: 0.9193
# Epoch 73/100
# 18/18 - 10s - loss: 0.3360 - acc: 0.8518 - mean_absolute_percentage_error: 117875784.0000 - auc: 0.9335 - val_loss: 0.4349 - val_acc: 0.7852 - val_mean_absolute_percentage_error: 148461424.0000 - val_auc: 0.8787
# Epoch 74/100
# 18/18 - 10s - loss: 0.3793 - acc: 0.8232 - mean_absolute_percentage_error: 124455120.0000 - auc: 0.9093 - val_loss: 0.3782 - val_acc: 0.8281 - val_mean_absolute_percentage_error: 134783360.0000 - val_auc: 0.9187
# Epoch 75/100
# 18/18 - 10s - loss: 0.3566 - acc: 0.8250 - mean_absolute_percentage_error: 123426424.0000 - auc: 0.9192 - val_loss: 0.3584 - val_acc: 0.8555 - val_mean_absolute_percentage_error: 131730184.0000 - val_auc: 0.9339
# Epoch 76/100
# 18/18 - 10s - loss: 0.3329 - acc: 0.8375 - mean_absolute_percentage_error: 118194976.0000 - auc: 0.9338 - val_loss: 0.4029 - val_acc: 0.8320 - val_mean_absolute_percentage_error: 141463408.0000 - val_auc: 0.9023
# Epoch 77/100
# 18/18 - 10s - loss: 0.3412 - acc: 0.8393 - mean_absolute_percentage_error: 117692888.0000 - auc: 0.9293 - val_loss: 0.3696 - val_acc: 0.8477 - val_mean_absolute_percentage_error: 135765568.0000 - val_auc: 0.9313
# Epoch 78/100
# 18/18 - 10s - loss: 0.3540 - acc: 0.8339 - mean_absolute_percentage_error: 118241224.0000 - auc: 0.9223 - val_loss: 0.3789 - val_acc: 0.8633 - val_mean_absolute_percentage_error: 138519904.0000 - val_auc: 0.9259
# Epoch 79/100
# 18/18 - 10s - loss: 0.3605 - acc: 0.8250 - mean_absolute_percentage_error: 119366920.0000 - auc: 0.9183 - val_loss: 0.3956 - val_acc: 0.8242 - val_mean_absolute_percentage_error: 140090400.0000 - val_auc: 0.9078
# Epoch 80/100
# 18/18 - 10s - loss: 0.3551 - acc: 0.8196 - mean_absolute_percentage_error: 119860456.0000 - auc: 0.9185 - val_loss: 0.3945 - val_acc: 0.8281 - val_mean_absolute_percentage_error: 138698688.0000 - val_auc: 0.9069
# Epoch 81/100
# 18/18 - 10s - loss: 0.3101 - acc: 0.8661 - mean_absolute_percentage_error: 108674816.0000 - auc: 0.9444 - val_loss: 0.3861 - val_acc: 0.8516 - val_mean_absolute_percentage_error: 132591616.0000 - val_auc: 0.9106
# Epoch 82/100
# 18/18 - 10s - loss: 0.3349 - acc: 0.8554 - mean_absolute_percentage_error: 115420288.0000 - auc: 0.9325 - val_loss: 0.3736 - val_acc: 0.8477 - val_mean_absolute_percentage_error: 134978976.0000 - val_auc: 0.9215
# Epoch 83/100
# 18/18 - 10s - loss: 0.3427 - acc: 0.8375 - mean_absolute_percentage_error: 118857536.0000 - auc: 0.9280 - val_loss: 0.3665 - val_acc: 0.8438 - val_mean_absolute_percentage_error: 134880320.0000 - val_auc: 0.9311
# Epoch 84/100
# 18/18 - 10s - loss: 0.3270 - acc: 0.8464 - mean_absolute_percentage_error: 111617616.0000 - auc: 0.9340 - val_loss: 0.4096 - val_acc: 0.8086 - val_mean_absolute_percentage_error: 138379344.0000 - val_auc: 0.8918
# Epoch 85/100
# 18/18 - 10s - loss: 0.3586 - acc: 0.8321 - mean_absolute_percentage_error: 120659848.0000 - auc: 0.9192 - val_loss: 0.3727 - val_acc: 0.8398 - val_mean_absolute_percentage_error: 135606000.0000 - val_auc: 0.9238
# Epoch 86/100
# 18/18 - 10s - loss: 0.3236 - acc: 0.8554 - mean_absolute_percentage_error: 111098248.0000 - auc: 0.9357 - val_loss: 0.4442 - val_acc: 0.7656 - val_mean_absolute_percentage_error: 141731024.0000 - val_auc: 0.8692
# Epoch 87/100
# 18/18 - 10s - loss: 0.3321 - acc: 0.8464 - mean_absolute_percentage_error: 112754720.0000 - auc: 0.9330 - val_loss: 0.3835 - val_acc: 0.8516 - val_mean_absolute_percentage_error: 138000880.0000 - val_auc: 0.9192
# Epoch 88/100
# 18/18 - 10s - loss: 0.3089 - acc: 0.8661 - mean_absolute_percentage_error: 109269912.0000 - auc: 0.9450 - val_loss: 0.3538 - val_acc: 0.8516 - val_mean_absolute_percentage_error: 129636568.0000 - val_auc: 0.9347
# Epoch 89/100
# 18/18 - 10s - loss: 0.3301 - acc: 0.8393 - mean_absolute_percentage_error: 113685032.0000 - auc: 0.9341 - val_loss: 0.3621 - val_acc: 0.8242 - val_mean_absolute_percentage_error: 129692160.0000 - val_auc: 0.9270
# Epoch 90/100
# 18/18 - 10s - loss: 0.3190 - acc: 0.8518 - mean_absolute_percentage_error: 113817128.0000 - auc: 0.9396 - val_loss: 0.3531 - val_acc: 0.8320 - val_mean_absolute_percentage_error: 126733880.0000 - val_auc: 0.9291
# Epoch 91/100
# 18/18 - 10s - loss: 0.3082 - acc: 0.8661 - mean_absolute_percentage_error: 108230696.0000 - auc: 0.9467 - val_loss: 0.3982 - val_acc: 0.8086 - val_mean_absolute_percentage_error: 135409488.0000 - val_auc: 0.9010
# Epoch 92/100
# 18/18 - 10s - loss: 0.3270 - acc: 0.8536 - mean_absolute_percentage_error: 112363384.0000 - auc: 0.9354 - val_loss: 0.4130 - val_acc: 0.8086 - val_mean_absolute_percentage_error: 133585040.0000 - val_auc: 0.8905
# Epoch 93/100
# 18/18 - 10s - loss: 0.3394 - acc: 0.8554 - mean_absolute_percentage_error: 113549552.0000 - auc: 0.9286 - val_loss: 0.3640 - val_acc: 0.8164 - val_mean_absolute_percentage_error: 131839680.0000 - val_auc: 0.9242
# Epoch 94/100
# 18/18 - 10s - loss: 0.3183 - acc: 0.8518 - mean_absolute_percentage_error: 109825584.0000 - auc: 0.9389 - val_loss: 0.3409 - val_acc: 0.8594 - val_mean_absolute_percentage_error: 125641632.0000 - val_auc: 0.9410
# Epoch 95/100
# 18/18 - 10s - loss: 0.3129 - acc: 0.8768 - mean_absolute_percentage_error: 110634264.0000 - auc: 0.9441 - val_loss: 0.3754 - val_acc: 0.8438 - val_mean_absolute_percentage_error: 130589056.0000 - val_auc: 0.9156
# Epoch 96/100
# 18/18 - 10s - loss: 0.3064 - acc: 0.8607 - mean_absolute_percentage_error: 108936576.0000 - auc: 0.9462 - val_loss: 0.3497 - val_acc: 0.8242 - val_mean_absolute_percentage_error: 127933888.0000 - val_auc: 0.9332
# 18/18 - 10s - loss: 0.3253 - acc: 0.8518 - mean_absolute_percentage_error: 111590168.0000 - auc: 0.9369 - val_loss: 0.3990 - val_acc: 0.8320 - val_mean_absolute_percentage_error: 141632912.0000 - val_auc: 0.9043
# Epoch 98/100
# 18/18 - 10s - loss: 0.3182 - acc: 0.8661 - mean_absolute_percentage_error: 109851400.0000 - auc: 0.9398 - val_loss: 0.3553 - val_acc: 0.8594 - val_mean_absolute_percentage_error: 125332424.0000 - val_auc: 0.9280
# Epoch 99/100
# 18/18 - 10s - loss: 0.3046 - acc: 0.8786 - mean_absolute_percentage_error: 106570712.0000 - auc: 0.9466 - val_loss: 0.3666 - val_acc: 0.8594 - val_mean_absolute_percentage_error: 132431744.0000 - val_auc: 0.9252
# Epoch 100/100
# 18/18 - 10s - loss: 0.3106 - acc: 0.8536 - mean_absolute_percentage_error: 106068392.0000 - auc: 0.9408 - val_loss: 0.3321 - val_acc: 0.8633 - val_mean_absolute_percentage_error: 123188752.0000 - val_auc: 0.9461

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valutation'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valutation'], loc='upper left')
plt.show()
